# %%
import tensorflow as tf
import tensorflow.keras.layers as tfl
from keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Image
import os

# %% [markdown]
# https://alexlenail.me/NN-SVG/LeNet.html

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
#@title To move images
# To move the sets

# import shutil

# total_nic_images = 206
# total_notnic_notperson_images = 210
# total_notnic_person_images = 465

# # 75/25 split

# # Nic
# train_threshold = int(total_nic_images * 0.75)

# for i in range(145, total_nic_images):

#   if i <= train_threshold:
#     shutil.move("/content/drive/MyDrive/Nicolas Cage/nic/Nic_Cage_" + str(i) + ".jpg", 
#                 "/content/drive/MyDrive/Nicolas Cage/dataset/train/class1") 
#   else:
#     shutil.move("/content/drive/MyDrive/Nicolas Cage/nic/Nic_Cage_" + str(i) + ".jpg", 
#                 "/content/drive/MyDrive/Nicolas Cage/dataset/test/class1") 

# # Notnic person
# train_threshold = int(total_notnic_person_images * 0.75)

# for i in range(500, 500+total_notnic_person_images):
#   if i <= train_threshold:
#     shutil.move("/content/drive/MyDrive/Nicolas Cage/not_nic_person/Cópia de 00" + str(i) + ".png", 
#                 "/content/drive/MyDrive/Nicolas Cage/dataset/train/class0") 
#   else:
#     shutil.move("/content/drive/MyDrive/Nicolas Cage/not_nic_person/Cópia de 00" + str(i) + ".png", 
#                 "/content/drive/MyDrive/Nicolas Cage/dataset/test/class0") 

# # Notninc for test
# train_threshold = int(total_notnic_notperson_images * 0.75)

# for i in range(total_notnic_notperson_images):
#   if i <= train_threshold:
#     shutil.move("/content/drive/MyDrive/Nicolas Cage/not_nic_not_person/not_nicolas_" + str(i) + ".jpg", 
#                 "/content/drive/MyDrive/Nicolas Cage/dataset/train/class0") 
#   else:
#     shutil.move("/content/drive/MyDrive/Nicolas Cage/not_nic_not_person/not_nicolas_" + str(i) + ".jpg", 
#                 "/content/drive/MyDrive/Nicolas Cage/dataset/test/class0")

# %%
#@title Moving content from one dir to another
# source: https://stackoverflow.com/questions/41826868/moving-all-files-from-one-directory-to-another-using-python


# import shutil
# import os
    
# source_dir = '/content/drive/MyDrive/Nicolas Cage/dataset/test/class0'
# target_dir = '/content/drive/MyDrive/Nicolas Cage/dataset/class0'
    
# file_names = os.listdir(source_dir)
    
# for file_name in file_names:
#     shutil.move(os.path.join(source_dir, file_name), target_dir)

# %%
#@title Create the datasets with augmentations
# Image augmentations 
# from keras.preprocessing.image import ImageDataGenerator

# train_datagen = ImageDataGenerator(rescale = 1./255)

# test_datagen = ImageDataGenerator(rescale = 1./255)

# training_set = train_datagen.flow_from_directory('/content/drive/MyDrive/Nicolas Cage/dataset/train',
#                                                  target_size = (200, 200),
#                                                  batch_size = 32,
#                                                  shuffle = False, 
#                                                  class_mode = "binary")

# test_set = test_datagen.flow_from_directory('/content/drive/MyDrive/Nicolas Cage/dataset/test',
#                                             target_size = (200, 200),
#                                             batch_size = 32,
#                                             shuffle = False,
#                                             class_mode = "binary")
# print(training_set.class_indices)
# print(training_set)

# %%
# Get the datasets
# source: https://www.tensorflow.org/tutorials/load_data/images

data_dir = "/content/drive/MyDrive/Nicolas Cage/dataset"
img_height, img_width = 180, 180
batch_size = 32

validation_split = 0.25
seed = 123

training_set = tf.keras.utils.image_dataset_from_directory(
                  data_dir,
                  label_mode='binary',
                  validation_split=validation_split,
                  subset="training",
                  seed=seed,
                  # image_size=(img_height, img_width),
                  batch_size=batch_size,
                  crop_to_aspect_ratio=True)

validation_set = tf.keras.utils.image_dataset_from_directory(
                  data_dir,
                  label_mode='binary',
                  validation_split=validation_split,
                  subset="validation",
                  seed=seed,
                  # image_size=(img_height, img_width),
                  batch_size=batch_size,
                  crop_to_aspect_ratio=True)
# Out:
# Found 879 files belonging to 2 classes.
# Using 660 files for training.
# Found 879 files belonging to 2 classes.
# Using 219 files for validation.

# %%
# Vizualize the training set
class_names = training_set.class_names

plt.figure(figsize=(10, 10))
for images, labels in training_set.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title("Nicolas Cage" if labels[i] else "Not Nicolas Cage")
    plt.axis("off")

# %%
# Configure the dataset for performance
AUTOTUNE = tf.data.AUTOTUNE

train_ds = training_set.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = validation_set.cache().prefetch(buffer_size=AUTOTUNE)

# %%
# The model
classifier = tf.keras.models.Sequential()

# Preprocessing Layers
classifier.add(tfl.Resizing(img_height, img_width))
classifier.add(tfl.Rescaling(1./255))

# Data Augmentation
classifier.add(tfl.RandomFlip("horizontal_and_vertical"))
classifier.add(tfl.RandomRotation(0.2))

# Convnet Layers
classifier.add(tfl.Conv2D(filters=32, kernel_size=(3, 3), input_shape = (180, 180, 3), activation = 'relu'))
classifier.add(tfl.MaxPooling2D(pool_size = (2, 2)))
classifier.add(tfl.Conv2D(filters=32, kernel_size=(3, 3), activation = 'relu'))
classifier.add(tfl.MaxPooling2D(pool_size=(2, 2)))
classifier.add(tfl.Conv2D(filters=64, kernel_size=(3, 3), activation = 'relu'))
classifier.add(tfl.MaxPooling2D(pool_size=(2, 2)))
classifier.add(tfl.Flatten())
classifier.add(tfl.Dense(units=64, activation = 'relu'))
classifier.add(tfl.Dropout(0.5))
classifier.add(tfl.Dense(1))
classifier.add(tfl.Activation('sigmoid'))

# Compile the model
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
classifier.build((None, img_height, img_width, 3))
classifier.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resizing_1 (Resizing)       (None, 180, 180, 3)       0
#
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  random_flip_1 (RandomFlip)  (None, 180, 180, 3)       0
#
#  random_rotation_1 (RandomRo  (None, 180, 180, 3)      0
#  tation)
#
#  conv2d_3 (Conv2D)           (None, 178, 178, 32)      896
#
#  max_pooling2d_3 (MaxPooling  (None, 89, 89, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 87, 87, 32)        9248
#
#  max_pooling2d_4 (MaxPooling  (None, 43, 43, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 41, 41, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 20, 20, 64)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 25600)             0
#
#  dense_2 (Dense)             (None, 64)                1638464
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 1)                 65
#
#  activation_1 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 1,667,169
# Trainable params: 1,667,169
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the
150
# 21/21 [==============================] - 25s 1s/step - loss: 0.0670 - accuracy: 0.9773 - val_loss: 0.1717 - val_accuracy: 0.9361
# Epoch 116/150
# 21/21 [==============================] - 25s 1s/step - loss: 0.0974 - accuracy: 0.9682 - val_loss: 0.2112 - val_accuracy: 0.9315
# Epoch 117/150
# 21/21 [==============================] - 25s 1s/step - loss: 0.0811 - accuracy: 0.9712 - val_loss: 0.1685 - val_accuracy: 0.9498
# Epoch 118/150
# 21/21 [==============================] - 26s 1s/step - loss: 0.0624 - accuracy: 0.9712 - val_loss: 0.1748 - val_accuracy: 0.9406
# Epoch 119/150
# 21/21 [==============================] - 25s 1s/step - loss: 0.0959 - accuracy: 0.9636 - val_loss: 0.2154 - val_accuracy: 0.9315
# Epoch 120/150
# 21/21 [==============================] - 25s 1s/step - loss: 0.0633 - accuracy: 0.9833 - val_loss: 0.2091 - val_accuracy: 0.9315
# Epoch 121/150
# 21/21 [==============================] - 25s 1s/step - loss: 0.0587 - accuracy: 0.9697 - val_loss: 0.1959 - val_accuracy: 0.9452
# Epoch 122/150
# 21/21 [==============================] - 25s 1s/step - loss: 0.0737 - accuracy: 0.9788 - val_loss: 0.1920 - val_accuracy: 0.9452
# Epoch 123/150
# 21/21 [==============================] - 25s 1s/step - loss: 0.0893 - accuracy: 0.9652 - val_loss: 0.1638 - val_accuracy: 0.9361
# Epoch 124/150
# 21/21 [==============================] - 25s 1s/step - loss: 0.0791 - accuracy: 0.9652 - val_loss: 0.2349 - val_accuracy: 0.8995
# Epoch 125/150
# 21/21 [==============================] - 25s 1s/step - loss: 0.1260 - accuracy: 0.9561 - val_loss: 0.1994 - val_accuracy: 0.9315
# Epoch 126/150
# 21/21 [==============================] - 25s 1s/step - loss: 0.0927 - accuracy: 0.9636 - val_loss: 0.1842 - val_accuracy: 0.9361
# Epoch 127/150
# 21/21 [==============================] - 25s 1s/step - loss: 0.0785 - accuracy: 0.9727 - val_loss: 0.1983 - val_accuracy: 0.9452
# Epoch 128/150
# 21/21 [==============================] - 25s 1s/step - loss: 0.0625 - accuracy: 0.9758 - val_loss: 0.1788 - val_accuracy: 0.9406
# Epoch 129/150
# 21/21 [==============================] - 25s 1s/step - loss: 0.0777 - accuracy: 0.9727 - val_loss: 0.2133 - val_accuracy: 0.9361
# Epoch 130/150
# 21/21 [==============================] - 25s 1s/step - loss: 0.0732 - accuracy: 0.9742 - val_loss: 0.2160 - val_accuracy: 0.9406
# Epoch 131/150
# 21/21 [==============================] - 25s 1s/step - loss: 0.0992 - accuracy: 0.9621 - val_loss: 0.2175 - val_accuracy: 0.9361
# Epoch 132/150
# 21/21 [==============================] - 25s 1s/step - loss: 0.0921 - accuracy: 0.9667 - val_loss: 0.2901 - val_accuracy: 0.9178
# Epoch 133/150
# 21/21 [==============================] - 25s 1s/step - loss: 0.1317 - accuracy: 0.9530 - val_loss: 0.2040 - val_accuracy: 0.9269
# Epoch 134/150
# 21/21 [==============================] - 25s 1s/step - loss: 0.1135 - accuracy: 0.9636 - val_loss: 0.2153 - val_accuracy: 0.9269
# Epoch 135/150
# 21/21 [==============================] - 25s 1s/step - loss: 0.0905 - accuracy: 0.9606 - val_loss: 0.1611 - val_accuracy: 0.9452
# Epoch 136/150
# 21/21 [==============================] - 25s 1s/step - loss: 0.0661 - accuracy: 0.9742 - val_loss: 0.1956 - val_accuracy: 0.9452
# Epoch 137/150
# 21/21 [==============================] - 25s 1s/step - loss: 0.0754 - accuracy: 0.9727 - val_loss: 0.2309 - val_accuracy: 0.9361
# Epoch 138/150
# 21/21 [==============================] - 25s 1s/step - loss: 0.0840 - accuracy: 0.9682 - val_loss: 0.2325 - val_accuracy: 0.9269
# Epoch 139/150
# 21/21 [==============================] - 25s 1s/step - loss: 0.0791 - accuracy: 0.9712 - val_loss: 0.2704 - val_accuracy: 0.9269
# Epoch 140/150
# 21/21 [==============================] - 25s 1s/step - loss: 0.0607 - accuracy: 0.9758 - val_loss: 0.2066 - val_accuracy: 0.9452
# Epoch 141/150
# 21/21 [==============================] - 25s 1s/step - loss: 0.0460 - accuracy: 0.9848 - val_loss: 0.1869 - val_accuracy: 0.9498
# Epoch 142/150
# 21/21 [==============================] - 25s 1s/step - loss: 0.0510 - accuracy: 0.9773 - val_loss: 0.2170 - val_accuracy: 0.9269
# Epoch 143/150
# 21/21 [==============================] - 25s 1s/step - loss: 0.0586 - accuracy: 0.9833 - val_loss: 0.2026 - val_accuracy: 0.9315
# Epoch 144/150
# 21/21 [==============================] - 25s 1s/step - loss: 0.0580 - accuracy: 0.9742 - val_loss: 0.2385 - val_accuracy: 0.9178
# Epoch 145/150
# 21/21 [==============================] - 25s 1s/step - loss: 0.0873 - accuracy: 0.9712 - val_loss: 0.1895 - val_accuracy: 0.9361
# Epoch 146/150
# 21/21 [==============================] - 25s 1s/step - loss: 0.0817 - accuracy: 0.9636 - val_loss: 0.2207 - val_accuracy: 0.9315
# Epoch 147/150
# 21/21 [==============================] - 25s 1s/step - loss: 0.0583 - accuracy: 0.9803 - val_loss: 0.2302 - val_accuracy: 0.9361
# Epoch 148/150
# 21/21 [==============================] - 25s 1s/step - loss: 0.0483 - accuracy: 0.9803 - val_loss: 0.2485 - val_accuracy: 0.9361
# Epoch 149/150
# 21/21 [==============================] - 25s 1s/step - loss: 0.0661 - accuracy: 0.9712 - val_loss: 0.2080 - val_accuracy: 0.9361
# Epoch 150/150
# 21/21 [==============================] - 25s 1s/step - loss: 0.0608 - accuracy: 0.9758 - val_loss: 0.2392 - val_accuracy: 0.9315

# %%
# Save the model
classifier.save("/content/drive/MyDrive/Nicolas Cage/h5/model_1.h5")

# %%
#@title Fit com data augmentation
# history = classifier.fit_generator(training_set,
#                         steps_per_epoch = 1000,
#                         epochs = 25,
#                         validation_data = test_set,
#                         validation_steps = 100)

# history = classifier.fit(training_set, epochs=10, batch_size=16)
# history = classifier.fit_generator(training_set, epochs=5, validation_data=test_set)

# %%
classifier.evaluate(val_ds)
# Out:
# 7/7 [==============================] - 2s 287ms/step - loss: 0.2392 - accuracy: 0.9315
# [0.23924677073955536, 0.931506872177124]

# %%
# Plot training & validation accuracy values

print(history.history.keys())

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
def is_this_nic(file, classifier):

  test_image = image.load_img(file, target_size = (180, 180))
  test_image = image.img_to_array(test_image)
  test_image = np.expand_dims(test_image, axis = 0)
  
  result = classifier.predict(test_image)
  print(result)

  # training_set.class_indices
  if result[0][0] >= 0.7:
      prediction = 'This is Nicolas Cage:'
      ret = True
  else:
      prediction = 'This is not Nicolas Cage:'
      ret = False

  print(prediction)
  img = Image(file, width = "400", height = "400")
  display(img)
  print("\n")
  print("\n")

  return ret

# %%
prediction_dir = '/content/drive/MyDrive/Nicolas Cage/prediction'
    
file_names = os.listdir(prediction_dir)
    
for file_name in file_names:
  is_this_nic(prediction_dir + "/" + file_name, classifier)

# %%
def label_predict(file, classifier):
  test_image = image.load_img(file, target_size = (180, 180))
  test_image = image.img_to_array(test_image)
  test_image = np.expand_dims(test_image, axis = 0)
  
  result = classifier.predict(test_image)

  if result[0][0] >= 0.7:
    return 1.0
  else:
    return 0.0

# %%
import sklearn
from sklearn.metrics import confusion_matrix

prediction_dir = '/content/drive/MyDrive/Nicolas Cage/prediction'
file_names = os.listdir(prediction_dir)

y_true = [1.0 if i < 9 else 0.0 for i in range(20) ]     
y_pred = [label_predict(prediction_dir + "/" + file_name, classifier) for file_name in file_names]

confusion_matrix(y_true, y_pred)

# C00 is true negatives
# C10 is false negatives
# C11 is true positives
# C01 is false positives
# Out:
# array([[8, 3],
#        [5, 4]])
